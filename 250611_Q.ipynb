# %% [markdown]
# <a href="https://colab.research.google.com/github/25d096/class01/blob/main/250611_Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [문제 1] 자기소개 저장하기
#
# 아래의 정보를 변수로 저장하고 출력해보세요.\
# \
# 	•	이름: 본인 이름\
# 	•	나이: 숫자로 저장\
# 	•	키(cm): 소수점 포함\
# 	•	출력 형식 예시:\
# \
# "안녕하세요. 제 이름은 OOO이고, 나이는 OO이며, 키는 OOOcm입니다."

# %% [markdown]
# ## [문제 2] 아래 코드의 출력 결과는?

# %%
for i in range(3):
    print("Hi!")

# %% [markdown]
# a) Hi!\
# b) Hi! Hi!\
# c) Hi! Hi! Hi!\
# d) 아무것도 출력되지 않음

# %% [markdown]
# ## [문제 3] 다음 중 for문을 올바르게 사용한 코드는?

# %% [markdown]
# ![스크린샷 2025-06-11 오후 1.20.05.png](data:image/png;base64,...)

# %% [markdown]
# ## [문제 4] 아래 코드가 출력하는 마지막 값은?

# %%
total = 0
for i in range(1, 5):
    total += i
print(total)

# %% [markdown]
# ## [문제 5] range(2, 10, 3)의 출력 결과는?

# %% [markdown]
# ## [실습 1] 숫자 1부터 5까지 출력하기
#
# 1\
# 2\
# 3\
# 4\
# 5

# %%
range(2, 10, 3)

# %% [markdown]
# ## [실습 2] 리스트의 평균 구하기

# %%
scores = [70, 85, 90, 100, 65]

# %% [markdown]
# ## [실습 3] 짝수만 출력하기

# %% [markdown]
# 1부터 20까지 수 중에서 짝수만 출력하세요.\
# 힌트: i % 2 == 0

# %% [markdown]
# ## [실습 4] 별 피라미드 찍기

# %% [markdown]
# ![스크린샷 2025-06-11 오후 1.23.31.png](data:image/png;base64,...)

# %% [markdown]
# 힌트: 문자열 곱셈 "*" * i

# %% [markdown]
# ## [실습 5] 사용자 입력 반복하기

# %%
# 입력 예시 (input 함수 사용)
입력하세요: 10
입력하세요: 20
입력하세요: 30
입력하세요: 25
입력하세요: 15

# 출력
총합: 100
